# %% [markdown]
# <a href="https://colab.research.google.com/github/Sankalpkarn/Data_Analytics/blob/main/Project_DA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing required libraries
import numpy as np  # NumPy for numerical operations
from PIL import Image  # PIL for working with images
import matplotlib.pyplot as plt  # Matplotlib for visualization
import requests  # Requests for making HTTP requests
from io import BytesIO  # BytesIO for handling binary data

# URL of the image to be fetched
image_url = "https://drive.google.com/uc?id=1SDlE4FD1fSIWIcXaNB63zu3MaE_uW08P"

# Sending a GET request to the image URL and storing the response
response = requests.get(image_url)

# Opening the image from the response content
img = Image.open(BytesIO(response.content))

# Converting the image to a NumPy array for processing
img_arr = np.array(img)

# Displaying the image using Matplotlib
plt.imshow(img_arr)
plt.show()

# %%
plt.imshow(img_arr[0:500,0:1000])#Select a specfic area of image | (0:500) it from vertical side | (0:1000) it is from horizontal side

# %%
plt.imshow(img_arr[0:450,0:1000,1])#0,1,2 only these three color codes are used to change the color of array image

# %%
plt.imshow(img_arr[0:1500,0:2000])#first Quater From Image Without Color

# %%
plt.imshow(img_arr[0:1500,2000:4000,0])#Second Quater From Image With Color

# %%
plt.imshow(img_arr[1500:2500,0:2000,1])#Third Quater From Image With Color

# %%
plt.imshow(img_arr[1500:2500,2000:4000,2])#Fourth Quater From Image With Color

# %%
img_arr[0:1500, 0:2500,0] = 0
img_arr[1500:, 0:2500,1] = 0
img_arr[0:1500, 2500:,2] = 0
img_arr[1500:, 2500:,0] = 0
img_arr[1500:, 2500:,1] = 0

plt.imshow(img_arr)
