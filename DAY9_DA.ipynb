# %%
#Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#Diference Between seaborn and matplotlib

# %%
- Matplotlib have more syntax
- Less attractive
- We can customize a lot

# %%
- Seaborn has lesser syntax
- More attractive
- less customization

# %%
# Countplot
sns.countplot(x='survived', data=titanic)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(x='pclass',color='red', data=titanic)
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
sns.countplot(y='pclass',color='red', data=titanic)
# Out:
# <Axes: xlabel='count', ylabel='pclass'>

# %%
titanic['survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
titanic['pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
titanic['who'].unique()
# Out:
# array(['man', 'woman', 'child'], dtype=object)

# %%
sns.countplot(x='pclass',hue='who', data=titanic)
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#sns.countplot(x='embarked', hue='survived', data=titanic)
sns.countplot(x='embarked',hue='survived', data=titanic)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 #sns.countplot(x='embarked', hue='survived', data=titanic)
# ----> 2 sns.countplot(x='embarked',hue='survived', data=titanic)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
# ...

# %%
# countplot
# bitfergration by embarked, pclass, sex, survived, alone
# info
# head
# tail
# min
# max
# count
# shape
# describe

# %%
titanic.head()
# boxplot
sns.boxplot(x='age', data=titanic)
# Out:
# <Axes: xlabel='age'>

# %%
# countplot
sns.countplot(x='survived', data=titanic)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
# bifergration 
sns.countplot(x='embarked',hue='who', data=titanic)
# Out:
# <Axes: xlabel='embarked', ylabel='count'>

# %%
sns.countplot(x='pclass',hue='who', data=titanic)
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
sns.countplot(x='sex',hue='who', data=titanic)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='survived',hue='who', data=titanic)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(x='alone',hue='who', data=titanic)
# Out:
# <Axes: xlabel='alone', ylabel='count'>

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
titanic.min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 titanic.min()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11285, in DataFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   11277 @doc(make_doc("min", ndim=2))
#   11278 def min(
#   11279     self,
#    (...)
#   11283     **kwargs,
#   11284 ):
# > 11285     result = super().min(axis, skipna, numeric_only, **kwargs)
#   11286     if isinstance(result, Series):
#   11287         result = result.__finalize__(self, method="min")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11960, in NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   11953 def min(
#   11954     self,
#   11955     axis: Axis | None = 0,
#    (...)
#   11958     **kwargs,
#   11959 ):
# > 11960     return self._stat_function(
#   11961         "min",
#   11962         nanops.nanmin,
# ...

# %%
titanic.max()

# %%
titanic.count()
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.shape
# Out:
# (891, 15)

# %%
#scatterplot
sns.scatterplot(x='age',y='fare', data=titanic)
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.regplot(x='fare',y='age', data=titanic)
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
sns.regplot(x='age',y='parch', data=titanic)
# Out:
# <Axes: xlabel='age', ylabel='parch'>

# %%
sns.regplot(x='age',y='pclass', data=titanic)
# Out:
# <Axes: xlabel='age', ylabel='pclass'>

# %%
sns.regplot(x='age',y='sibsp', data=titanic)
# Out:
# <Axes: xlabel='age', ylabel='sibsp'>

# %%
sns.regplot(x='pclass',y='sibsp', data=titanic)
# Out:
# <Axes: xlabel='pclass', ylabel='sibsp'>

# %%
sns.regplot(x='parch',y='sibsp', data=titanic)
# Out:
# <Axes: xlabel='parch', ylabel='sibsp'>

# %%
#Null Values

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
x=titanic['age'].median()
x
# Out:
# 28.0

# %%
titanic.age.fillna(x,inplace=True)
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#titanic.drop(columns=['deck'], inplace=True)
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
sns.heatmap([[1,.30,.40],[.50,.1,.20],[.70,.20,1]], annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap([[1,.30,.40,],[.50,.1,.20,],[.70,.20,1,],
             [1,.30,.40,],[.50,.1,.20,],[.70,.20,1]], annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap([[1,.50,.40,.30,.20,.10],
            [.50,1,.20,.10,.40,.30],
            [.40,.20,1,.50,.30,.60],
            [.30,.10,.50,1,.60,.20],
            [.20,.40,.30,.60,1,.50],
            [.10,.30,.60,.20,.50,1]],annot=True)
# Out:
# <Axes: >
